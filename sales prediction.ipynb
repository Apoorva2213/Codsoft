# %% [markdown]
# STEP1 IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# STEP2 IMPORTING DATASET AS DATAFRAME

# %%
data= pd.DataFrame(pd.read_csv("advertising.csv"))
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# STEP3 DATA PREPROCESSING

# %%
data.shape
# Out:
# (200, 4)

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
#There are no null values in the given dataset

# %% [markdown]
# STEP4 DATA VISUALIZATION

# %%
#TV VS Sales

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='TV', y='Sales', data=data)
plt.title('TV Advertising vs Sales')
plt.xlabel('TV Advertising Spending')
plt.ylabel('Sales')
plt.show()

# %%
#Radio VS Sales

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Radio', y='Sales', data=data)
plt.title('Radio Advertising vs Sales')
plt.xlabel('Radio Advertising Spending')
plt.ylabel('Sales')
plt.show()

# %%
#Newspaper VS Sales

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Newspaper', y='Sales', data=data)
plt.title('Newspaper Advertising vs Sales')
plt.xlabel('Newspaper Advertising Spending')
plt.ylabel('Sales')
plt.show()

# %%
#Relationship between all variables

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# STEP5 Train Data

# %%
X = data.drop('Sales', axis=1)
y = data['Sales']
X.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
len(X_train)
# Out:
# 160

# %%
len(X_test)
# Out:
# 40

# %%
#Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# STEP6 PREDICTING MODEL

# %%
y_pred = model.predict(X_train)

# %%
y_pred_test = model.predict(X_test)

# %%
X_test['Sales Predicted']=y_pred_test;
X_test
# Out:
#         TV  Radio  Newspaper  Sales Predicted
# 112  175.7   15.4        2.4        15.778786
# 165  234.5    3.4       84.8        18.139634
# 12    23.8   35.1       65.9         9.719884
# 73   129.4    5.7       31.3        12.357547
# 144   96.2   14.8       38.9        11.499283
# 20   218.4   27.7       53.4        19.617089
# 199  232.1    8.6        8.7        18.211406
# 8      8.6    2.1        1.0         5.205011
# 39   228.0   37.7       32.0        21.081440
# 88    88.3   25.5       73.4        12.315529
# 81   239.8    4.1       36.9        18.294983
# 197  177.0    9.3        6.4        15.240080
# 69   216.8   43.9       27.2        21.081944
# 160  172.5   18.1       30.7        16.003604
# 25   262.9    3.5       19.5        19.429215
# 99   135.2   41.7       45.9        16.444731
# 151  121.0    8.4       48.7        12.248662
# 23   228.3   16.9       26.2        18.932425
# 138   43.0   25.9       20.5         9.632635
# 159  131.7   18.4       34.6        13.805339
# 89   109.8   47.8       51.4        15.698036
# 82    75.3   20.3       32.5        10.886794
# 24    62.3   12.6       18.3         9.317007
# 174  222.4    3.4       13.1        17.161481
# 137  273.7   28.9       59.7        22.812340
# 83    68.4   44.5       35.6        13.010573
# 107   90.4    0.3       23.2         9.619630
# 34    95.7    1.4        7.4         9.955833
# 97   184.9   21.0       22.0        16.946790
# 167  206.8    5.2       19.4        16.515309
# 123  123.1   34.6       12.4        14.902240
# 157  149.8    1.3       24.3        12.997384
# 75    16.9   43.7       89.4        10.327223
# 152  197.6   23.3       14.2        17.848668
# 117   76.4    0.8       14.8         8.863801
# 149   44.7   25.8       20.6         9.716368
# 63   102.7   29.6        8.4        13.247286
# 54   262.7   28.8       15.9        22.005871
# 125   87.2   11.8       25.9        10.638548
# 80    76.4   26.7       22.3        11.561512

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print('R^2: ', r2_score(y_train, y_pred))
print('MAE: ',mean_absolute_error(y_train, y_pred))
print('MSE: ', mean_squared_error(y_train, y_pred))
print('RMSE: ', np.sqrt(mean_squared_error(y_train, y_pred)))
# Out:
# R^2:  0.9019923976035102
# MAE:  1.2899485536992972
# MSE:  2.9700888061443824
# RMSE:  1.7233945590445567
